# %% [markdown]
# <a href="https://colab.research.google.com/github/pas081bct015/FDSlab/blob/main/lab6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Example dataset
data = {'Color': ['Red', 'Blue', 'Green', 'Blue', 'Red']}
df = pd.DataFrame(data)
# One-hot encoding
encoded_df = pd.get_dummies(df, columns=['Color'], drop_first=False)
print(encoded_df)

# %%
#label encoding

from sklearn.preprocessing import LabelEncoder
# Example
label_encoder = LabelEncoder()
df['Color_Label'] = label_encoder.fit_transform(df['Color'])
print(df)

# %%
#frecuency encoding

frequency_map = df['Color'].value_counts().to_dict()
df['Color_Frequency'] = df['Color'].map(frequency_map)
print(df)

# %%
#Corelation analysis

import pandas as pd
import numpy as np

# ---- Option 1: Just keep the numeric columns and calculate correlation ----

numerical_df = df.select_dtypes(include=np.number)
correlation = numerical_df.corr()
print(correlation['Feature1'])


# ---- Option 2: Convert Color_Label and Color_Frequency to numbers, then correlate ----

df['Color_Label'] = pd.to_numeric(df['Color_Label'], errors='coerce')
df['Color_Frequency'] = pd.to_numeric(df['Color_Frequency'], errors='coerce')
numerical_df = df.drop(columns=['Color'])
correlation = numerical_df.corr()
print(correlation['Feature1'])

# %%
# Chi-Square Test

import pandas as pd
import numpy as np
from sklearn.feature_selection import f_regression, SelectKBest

# Add a random target column to the dataframe
df['Target'] = np.random.rand(len(df))

# Set X as all the features and y as the target
X = df.drop(columns=['Target', 'Color'])
y = df['Target']

# Drop any rows that have missing values
X = X.dropna()
y = y[X.index]  # Make sure y matches the rows we kept in X

# Pick the 5 best features using f_regression
X_new = SelectKBest(f_regression, k=5).fit_transform(X, y)

print(X_new)

# %%
#  PCA (Principal Component Analysis)

from sklearn.linear_model import Lasso
lasso = Lasso(alpha=0.01)
lasso.fit(X, y)
print(lasso.coef_)
# Out:
# [ 0.12757033  0.30580765  0.         -0.53488396]
