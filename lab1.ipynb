# %% [markdown]
# <a href="https://colab.research.google.com/github/pas081bct015/FDSlab/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age=25
print(type(age))
# Out:
# <class 'int'>

# %%
name= "Nabin"
print(name[0])
# Out:
# N

# %%
fruits = ["apple","banana","mango"]
print(fruits[1])
# Out:
# banana

# %%
x=10
y=3
result = (x+y)*5
print(result)
# Out:
# 65
