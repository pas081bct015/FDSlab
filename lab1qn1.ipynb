# %% [markdown]
# <a href="https://colab.research.google.com/github/pas081bct015/FDSlab/blob/main/lab1qn1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=int(input("enter any no:"))
if x % 2 == 0:
  print("even")
else:
  print("odd")
# Out:
# enter any no:17
# odd

# %%
x=int(input("enter any no: "))
if x > 0:
  print("positive")
elif x==0:
  print("zero")
else:
  print("negative")
# Out:
# enter any no: -15
# negative

# %%
x = float(input("enter first no: "))
y = float(input("enter second no: "))
sum = x + y
print(sum)
# Out:
# enter first no: 1.5
# enter second no: 1.6
# 3.1

# %%
x = int(input("enter a no: "))
temp = 1
while x != 0:
  temp = temp * x
  x = x - 1
print(temp)
# Out:
# enter a no: 4
# 24

# %%
x = int(input("enter a no: "))
temp = 1
for i in range(1,x+1):
  temp = temp * i
print(temp)
# Out:
# enter a no: 4
# 24
